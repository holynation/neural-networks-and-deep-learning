# %%
# !git clone https://github.com/holynation/neural-networks-and-deep-learning.git

# !python /content/neural-networks-and-deep-learning/main.py /content/neural-networks-and-deep-learning/data/mnist.pkl.gz
# Out:
# Cloning into 'neural-networks-and-deep-learning'...
# remote: Enumerating objects: 1240, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 1240 (delta 29), reused 28 (delta 22), pack-reused 1176 (from 3)
# Receiving objects: 100% (1240/1240), 20.46 MiB | 11.74 MiB/s, done.
# Resolving deltas: 100% (614/614), done.
# Epoch 0 training complete
# Cost on training data: 0.593982789198201
# Accuracy on training data: 45574 / 50000
# Cost on evaluation data: 0.6874530345221808
# Accuracy on evaluation data: 9151 / 10000
# Epoch 1 training complete
# Cost on training data: 0.49982100790965867
# Accuracy on training data: 46357 / 50000
# Cost on evaluation data: 0.6127274529610987
# Accuracy on evaluation data: 9253 / 10000
# Epoch 2 training complete
# Cost on training data: 0.47013489432180744
# Accuracy on training data: 46801 / 50000
# Cost on evaluation data: 0.6067736861784585
# Accuracy on evaluation data: 9302 / 10000
# Epoch 3 training complete
# Cost on training data: 0.4068973485857312
# Accuracy on training data: 47055 / 50000
# Cost on evaluation data: 0.5470501267159804
# Accuracy on evaluation data: 9358 / 10000
# Epoch 4 training complete
# Cost on training data: 0.3855209525311606
# Accuracy on training data: 47368 / 50000
# Cost on evaluation data: 0.5409270436003673
# Accuracy on evaluation data: 9392 / 10000
# Epoch 5 training complete
# Cost on training data: 0.3651386843554234
# Accuracy on training data: 47447 / 50000
# Cost on evaluation data: 0.5310187561700825
# Accuracy on evaluation data: 9408 / 10000
# Epoch 6 training complete
# Cost on training data: 0.33939067161968245
# Accuracy on training data: 47733 / 50000
# Cost on evaluation data: 0.5181824147701469
# Accuracy on evaluation data: 9422 / 10000
# Epoch 7 training complete
# Cost on training data: 0.3332544779909439
# Accuracy on training data: 47794 / 50000
# Cost on evaluation data: 0.5023253322200419
# Accuracy on evaluation data: 9466 / 10000
# Epoch 8 training complete
# Cost on training data: 0.3675646831748431
# Accuracy on training data: 47565 / 50000
# Cost on evaluation data: 0.5443440317986781
# Accuracy on evaluation data: 9399 / 10000
# Epoch 9 training complete
# Cost on training data: 0.3110709948202639
# Accuracy on training data: 47994 / 50000
# Cost on evaluation data: 0.499465636984218
# Accuracy on evaluation data: 9451 / 10000
# Epoch 10 training complete
# Cost on training data: 0.31486111993752186
# Accuracy on training data: 47958 / 50000
# Cost on evaluation data: 0.513925004612958
# Accuracy on evaluation data: 9438 / 10000
# Epoch 11 training complete
# Cost on training data: 0.32831198771428877
# Accuracy on training data: 47824 / 50000
# Cost on evaluation data: 0.5227414762311043
# Accuracy on evaluation data: 9425 / 10000
# Epoch 12 training complete
# Cost on training data: 0.28891849477948595
# Accuracy on training data: 48182 / 50000
# Cost on evaluation data: 0.49062776234364136
# Accuracy on evaluation data: 9472 / 10000
# Epoch 13 training complete
# Cost on training data: 0.28163837745123055
# Accuracy on training data: 48318 / 50000
# Cost on evaluation data: 0.49888097425713696
# Accuracy on evaluation data: 9485 / 10000
# Epoch 14 training complete
# Cost on training data: 0.3044427088050797
# Accuracy on training data: 47996 / 50000
# Cost on evaluation data: 0.5145510397319555
# Accuracy on evaluation data: 9432 / 10000
# Epoch 15 training complete
# Cost on training data: 0.2798671135629706
# Accuracy on training data: 48259 / 50000
# Cost on evaluation data: 0.5050905403113671
# Accuracy on evaluation data: 9475 / 10000
# Epoch 16 training complete
# Cost on training data: 0.26721763483282324
# Accuracy on training data: 48352 / 50000
# Cost on evaluation data: 0.49663472611188264
# Accuracy on evaluation data: 9467 / 10000
# Epoch 17 training complete
# Cost on training data: 0.25842795318116796
# Accuracy on training data: 48410 / 50000
# Cost on evaluation data: 0.4953341872586947
# Accuracy on evaluation data: 9478 / 10000
# Epoch 18 training complete
# Cost on training data: 0.24914333121523174
# Accuracy on training data: 48505 / 50000
# Cost on evaluation data: 0.4783402871467905
# Accuracy on evaluation data: 9512 / 10000
# Epoch 19 training complete
# Cost on training data: 0.2555073488869823
# Accuracy on training data: 48448 / 50000
# Cost on evaluation data: 0.48591194605973764
# Accuracy on evaluation data: 9509 / 10000
# Epoch 20 training complete
# Cost on training data: 0.2694718896090872
# Accuracy on training data: 48322 / 50000
# Cost on evaluation data: 0.5168730746894555
# Accuracy on evaluation data: 9478 / 10000
# Epoch 21 training complete
# Cost on training data: 0.24622325025169833
# Accuracy on training data: 48516 / 50000
# Cost on evaluation data: 0.5026682820538229
# Accuracy on evaluation data: 9478 / 10000
# Epoch 22 training complete
# Cost on training data: 0.2549843278661303
# Accuracy on training data: 48419 / 50000
# Cost on evaluation data: 0.5060352655142384
# Accuracy on evaluation data: 9489 / 10000
# Epoch 23 training complete
# Cost on training data: 0.24489776211238048
# Accuracy on training data: 48535 / 50000
# Cost on evaluation data: 0.49742370226664334
# Accuracy on evaluation data: 9495 / 10000
# Epoch 24 training complete
# Cost on training data: 0.22692090297433834
# Accuracy on training data: 48697 / 50000
# Cost on evaluation data: 0.4971678330300421
# Accuracy on evaluation data: 9498 / 10000
# Epoch 25 training complete
# Cost on training data: 0.246296876859502
# Accuracy on training data: 48590 / 50000
# Cost on evaluation data: 0.5233792339782518
# Accuracy on evaluation data: 9466 / 10000
# Epoch 26 training complete
# Cost on training data: 0.22966992563780636
# Accuracy on training data: 48670 / 50000
# Cost on evaluation data: 0.5083570952742177
# Accuracy on evaluation data: 9492 / 10000
# Epoch 27 training complete
# Cost on training data: 0.23418853334359008
# Accuracy on training data: 48582 / 50000
# Cost on evaluation data: 0.51710586603603
# Accuracy on evaluation data: 9476 / 10000
# Epoch 28 training complete
# Cost on training data: 0.22091668208183113
# Accuracy on training data: 48752 / 50000
# Cost on evaluation data: 0.5078999024825976
# Accuracy on evaluation data: 9491 / 10000
# Epoch 29 training complete
# Cost on training data: 0.24147139769165255
# Accuracy on training data: 48559 / 50000
# Cost on evaluation data: 0.5189243579793423
# Accuracy on evaluation data: 9476 / 10000

# %%
# Out:
# Epoch 0 training complete
# Accuracy on evaluation data: 9031 / 10000
# Epoch 1 training complete
# Accuracy on evaluation data: 9234 / 10000
# Epoch 2 training complete
# Accuracy on evaluation data: 9285 / 10000
# Epoch 3 training complete
# Accuracy on evaluation data: 9359 / 10000
# Epoch 4 training complete
# Accuracy on evaluation data: 9340 / 10000
# Epoch 5 training complete
# Accuracy on evaluation data: 9336 / 10000
# Epoch 6 training complete
# Accuracy on evaluation data: 9366 / 10000
# Epoch 7 training complete
# Accuracy on evaluation data: 9383 / 10000
# Epoch 8 training complete
# Accuracy on evaluation data: 9423 / 10000
# Epoch 9 training complete
# Accuracy on evaluation data: 9401 / 10000
# Epoch 10 training complete
# Accuracy on evaluation data: 9428 / 10000
# Epoch 11 training complete
# Accuracy on evaluation data: 9421 / 10000
# Epoch 12 training complete
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 4
#       2 net = network2.Network([784, 30, 10], cost=network2.CrossEntropyCost)
#       3 net.large_weight_initializer()
# ----> 4 net.SGD(training_data, 30, 10, 0.5, evaluation_data=test_data,monitor_evaluation_accuracy=True)
#
# File ~/Documents/GitHub/neural-networks-and-deep-learning/src/network2.py:185, in Network.SGD(self, training_data, epochs, mini_batch_size, eta, lmbda, evaluation_data, monitor_evaluation_cost, monitor_evaluation_accuracy, monitor_training_cost, monitor_training_accuracy)
#     182         accuracy = self.accuracy(evaluation_data)
#     183         evaluation_accuracy.append(accuracy)
#     184         print("Accuracy on evaluation data: {} / {}".format(
# --> 185             self.accuracy(evaluation_data), n_data))
#     186     print
#     187 return evaluation_cost, evaluation_accuracy, \
#     188     training_cost, training_accuracy
#
# File ~/Documents/GitHub/neural-networks-and-deep-learning/src/network2.py:270, in Network.accuracy(self, data, convert)
#     267     results = [(np.argmax(self.feedforward(x)), np.argmax(y))
#     268                for (x, y) in data]
#     269 else:
# --> 270     results = [(np.argmax(self.feedforward(x)), y)
#     271                 for (x, y) in data]
#     272 return sum(int(x == y) for (x, y) in results)
#
# File ~/Documents/GitHub/neural-networks-and-deep-learning/src/network2.py:126, in Network.feedforward(self, a)
#     124 """Return the output of the network if ``a`` is input."""
#     125 for b, w in zip(self.biases, self.weights):
# --> 126     a = sigmoid(np.dot(w, a)+b)
#     127 return a
#
# KeyboardInterrupt:
